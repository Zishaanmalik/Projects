# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv('Healthcare-Diabetes.csv')
data
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        1            6      148             72             35        0  33.6
# 1        2            1       85             66             29        0  26.6
# 2        3            8      183             64              0        0  23.3
# 3        4            1       89             66             23       94  28.1
# 4        5            0      137             40             35      168  43.1
# ...    ...          ...      ...            ...            ...      ...   ...
# 2763  2764            2       75             64             24       55  29.7
# 2764  2765            8      179             72             42      130  32.7
# 2765  2766            6       85             78              0        0  31.2
# 2766  2767            0      129            110             46      130  67.1
# 2767  2768            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.627   50        1
# 1                        0.351   31        0
# 2                        0.672   32        1
# 3                        0.167   21        0
# 4                        2.288   33        1
# ...                        ...  ...      ...
# 2763                     0.370   33        0
# 2764                     0.719   36        1
# 2765                     0.382   42        0
# 2766                     0.319   26        1
# 2767                     0.547   25        0
#
# [2768 rows x 10 columns]

# %%
data=data.drop(['Id'],axis=1)
data
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               6      148             72             35        0  33.6
# 1               1       85             66             29        0  26.6
# 2               8      183             64              0        0  23.3
# 3               1       89             66             23       94  28.1
# 4               0      137             40             35      168  43.1
# ...           ...      ...            ...            ...      ...   ...
# 2763            2       75             64             24       55  29.7
# 2764            8      179             72             42      130  32.7
# 2765            6       85             78              0        0  31.2
# 2766            0      129            110             46      130  67.1
# 2767            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.627   50        1
# 1                        0.351   31        0
# 2                        0.672   32        1
# 3                        0.167   21        0
# 4                        2.288   33        1
# ...                        ...  ...      ...
# 2763                     0.370   33        0
# 2764                     0.719   36        1
# 2765                     0.382   42        0
# 2766                     0.319   26        1
# 2767                     0.547   25        0
#
# [2768 rows x 9 columns]

# %%
plt.figure(figsize=(16,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data,hue='Outcome')

# %%
features = data.drop(['Outcome'], axis=1).columns

for feature in features:
    plt.figure(figsize=(6,4))
    sns.kdeplot(data=data,x=feature,fill=True ,hue='Outcome')
    plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,BaggingClassifier, GradientBoostingClassifier,AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
features=data.drop(['Outcome'],axis=1)
features
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               6      148             72             35        0  33.6
# 1               1       85             66             29        0  26.6
# 2               8      183             64              0        0  23.3
# 3               1       89             66             23       94  28.1
# 4               0      137             40             35      168  43.1
# ...           ...      ...            ...            ...      ...   ...
# 2763            2       75             64             24       55  29.7
# 2764            8      179             72             42      130  32.7
# 2765            6       85             78              0        0  31.2
# 2766            0      129            110             46      130  67.1
# 2767            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age
# 0                        0.627   50
# 1                        0.351   31
# 2                        0.672   32
# 3                        0.167   21
# 4                        2.288   33
# ...                        ...  ...
# 2763                     0.370   33
# 2764                     0.719   36
# 2765                     0.382   42
# 2766                     0.319   26
# 2767                     0.547   25
#
# [2768 rows x 8 columns]

# %%
target=pd.DataFrame(data.Outcome)
target
# Out:
#       Outcome
# 0           1
# 1           0
# 2           1
# 3           0
# 4           1
# ...       ...
# 2763        0
# 2764        1
# 2765        0
# 2766        1
# 2767        0
#
# [2768 rows x 1 columns]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
import joblib
import warnings

# %%
model_results = pd.DataFrame(columns=[
"Model","Train_Acc","Test_Acc",
"Train_Prec","Test_Prec",
"Train_Rec","Test_Rec",
"Train_F1","Test_F1" ])

# %%
def clasicalmodels(model,xtrain=xtrain,ytrain=ytrain,xtest=xtest,ytest=ytest):
    warnings.filterwarnings('ignore')
    model.fit(xtrain, ytrain)
    warnings.filterwarnings('ignore')
    ypred_train = model.predict(xtrain)
    ypred_test = model.predict(xtest)
    print(model,':')

    tr_acc = accuracy_score(ytrain, ypred_train)
    te_acc = accuracy_score(ytest, ypred_test)
    tr_p = precision_score(ytrain, ypred_train, average="weighted")
    te_p = precision_score(ytest, ypred_test, average="weighted")
    tr_r = recall_score(ytrain, ypred_train, average="weighted")
    te_r = recall_score(ytest, ypred_test, average="weighted")
    tr_f = f1_score(ytrain, ypred_train, average="weighted")
    te_f = f1_score(ytest, ypred_test, average="weighted")
    
    print(f"Train Accuracy : {tr_acc:.4f}")
    print(f"Test  Accuracy : {te_acc:.4f}")
    print(f"Train Precision: {tr_p:.4f}")
    print(f"Test  Precision: {te_p:.4f}")
    print(f"Train Recall   : {tr_r:.4f}")
    print(f"Test  Recall   : {te_r:.4f}")    
    print(f"Train F1 Score : {tr_f:.4f}")
    print(f"Test  F1 Score : {te_f:.4f}")

    model_results.loc[len(model_results)] = [model.__class__.__name__,tr_acc,te_acc,tr_p, te_p, tr_r, te_r, tr_f, te_f]

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    sns.heatmap(confusion_matrix(ytrain, ypred_train),annot=True, fmt='d', ax=axes[0], cmap="Blues", cbar=False)
    axes[0].set_title("Train Confusion Matrix")
    axes[0].set_xlabel("Predicted")
    axes[0].set_ylabel("Actual")
    
    sns.heatmap(confusion_matrix(ytest, ypred_test),annot=True, fmt='d', ax=axes[1], cmap="Blues", cbar=False)
    axes[1].set_title("Test Confusion Matrix")
    axes[1].set_xlabel("Predicted")
    axes[1].set_ylabel("Actual")
    plt.show()
        
    from pathlib import Path
    root=Path("models")
    root.mkdir(exist_ok=True)
    path = root / f"{str(model.__class__.__name__)}.pkl"
    joblib.dump(model, path)

    return model

# %%
# DecisionTreeClassifier
decitree=clasicalmodels(DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=2,random_state=42))
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=2,
#                        random_state=42) :
# Train Accuracy : 0.8446
# Test  Accuracy : 0.8466
# Train Precision: 0.8430
# Test  Precision: 0.8448
# Train Recall   : 0.8446
# Test  Recall   : 0.8466
# Train F1 Score : 0.8414
# Test  F1 Score : 0.8430

# %%
# RandomForestClassifier
warnings.filterwarnings('ignore')
ranfor=clasicalmodels(RandomForestClassifier(n_estimators=18,random_state=86))
# Out:
# RandomForestClassifier(n_estimators=18, random_state=86) :
# Train Accuracy : 0.9995
# Test  Accuracy : 0.9783
# Train Precision: 0.9995
# Test  Precision: 0.9784
# Train Recall   : 0.9995
# Test  Recall   : 0.9783
# Train F1 Score : 0.9995
# Test  F1 Score : 0.9783

# %%
# LogisticRegression
warnings.filterwarnings('ignore')
logcls=clasicalmodels(LogisticRegression(max_iter=5000,random_state=86))
# Out:
# LogisticRegression(max_iter=5000, random_state=86) :
# Train Accuracy : 0.7841
# Test  Accuracy : 0.7744
# Train Precision: 0.7796
# Test  Precision: 0.7689
# Train Recall   : 0.7841
# Test  Recall   : 0.7744
# Train F1 Score : 0.7766
# Test  F1 Score : 0.7633

# %%
# KNeighborsClassifier
warnings.filterwarnings('ignore')
knc=clasicalmodels(KNeighborsClassifier(n_neighbors=6))
warnings.filterwarnings('ignore')
# Out:
# KNeighborsClassifier(n_neighbors=6) :
# Train Accuracy : 0.8902
# Test  Accuracy : 0.8159
# Train Precision: 0.8954
# Test  Precision: 0.8135
# Train Recall   : 0.8902
# Test  Recall   : 0.8159
# Train F1 Score : 0.8864
# Test  F1 Score : 0.8092

# %%
# SVC
warnings.filterwarnings('ignore')
svc=clasicalmodels(SVC(C = 100 ,random_state=42, gamma = 100))
# Out:
# SVC(C=100, gamma=100, random_state=42) :
# Train Accuracy : 1.0000
# Test  Accuracy : 0.9874
# Train Precision: 1.0000
# Test  Precision: 0.9876
# Train Recall   : 1.0000
# Test  Recall   : 0.9874
# Train F1 Score : 1.0000
# Test  F1 Score : 0.9873

# %%
# GaussianNB
warnings.filterwarnings('ignore')
gauss=clasicalmodels(GaussianNB())
# Out:
# GaussianNB() :
# Train Accuracy : 0.7669
# Test  Accuracy : 0.7690
# Train Precision: 0.7621
# Test  Precision: 0.7636
# Train Recall   : 0.7669
# Test  Recall   : 0.7690
# Train F1 Score : 0.7632
# Test  F1 Score : 0.7647

# %%
# BaggingClassifier

# %%
def clasicalmodels(model,pathname,xtrain=xtrain,ytrain=ytrain,xtest=xtest,ytest=ytest):
    model.fit(xtrain, ytrain)
    ypred_train = model.predict(xtrain)
    ypred_test = model.predict(xtest)
    print(model,':')
    
    tr_acc = accuracy_score(ytrain, ypred_train)
    te_acc = accuracy_score(ytest, ypred_test)
    tr_p = precision_score(ytrain, ypred_train, average="weighted")
    te_p = precision_score(ytest, ypred_test, average="weighted")
    tr_r = recall_score(ytrain, ypred_train, average="weighted")
    te_r = recall_score(ytest, ypred_test, average="weighted")
    tr_f = f1_score(ytrain, ypred_train, average="weighted")
    te_f = f1_score(ytest, ypred_test, average="weighted")
    
    print(f"Train Accuracy : {tr_acc:.4f}")
    print(f"Test  Accuracy : {te_acc:.4f}")
    print(f"Train Precision: {tr_p:.4f}")
    print(f"Test  Precision: {te_p:.4f}")
    print(f"Train Recall   : {tr_r:.4f}")
    print(f"Test  Recall   : {te_r:.4f}")    
    print(f"Train F1 Score : {tr_f:.4f}")
    print(f"Test  F1 Score : {te_f:.4f}")

    model_results.loc[len(model_results)] = [pathname,tr_acc,te_acc,tr_p, te_p, tr_r, te_r, tr_f, te_f]


    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    sns.heatmap(confusion_matrix(ytrain, ypred_train),annot=True, fmt='d', ax=axes[0], cmap="Blues", cbar=False)
    axes[0].set_title("Train Confusion Matrix")
    axes[0].set_xlabel("Predicted")
    axes[0].set_ylabel("Actual")
    
    sns.heatmap(confusion_matrix(ytest, ypred_test),annot=True, fmt='d', ax=axes[1], cmap="Blues", cbar=False)
    axes[1].set_title("Test Confusion Matrix")
    axes[1].set_xlabel("Predicted")
    axes[1].set_ylabel("Actual")
    plt.show()
        
    from pathlib import Path
    root=Path("models")
    root.mkdir(exist_ok=True)
    path = root / f"{str(pathname)}.pkl"
    joblib.dump(model, path)

    return model

# %%
# BaggingClassifier with LogisticRegression
warnings.filterwarnings('ignore')
bag_logr=clasicalmodels(BaggingClassifier(n_estimators=15,estimator=logcls),'BaggingClassifier_LogisticRegression')
# Out:
# BaggingClassifier(estimator=LogisticRegression(max_iter=5000, random_state=86),
#                   n_estimators=15) :
# Train Accuracy : 0.7818
# Test  Accuracy : 0.7762
# Train Precision: 0.7770
# Test  Precision: 0.7706
# Train Recall   : 0.7818
# Test  Recall   : 0.7762
# Train F1 Score : 0.7746
# Test  F1 Score : 0.7660

# %%
# BaggingClassifier with SVC
warnings.filterwarnings('ignore')
bag_svc=clasicalmodels(BaggingClassifier(n_estimators=15,estimator=svc),'BaggingClassifier_SVC')
# Out:
# BaggingClassifier(estimator=SVC(C=100, gamma=100, random_state=42),
#                   n_estimators=15) :
# Train Accuracy : 0.9968
# Test  Accuracy : 0.9783
# Train Precision: 0.9969
# Test  Precision: 0.9790
# Train Recall   : 0.9968
# Test  Recall   : 0.9783
# Train F1 Score : 0.9968
# Test  F1 Score : 0.9782

# %%
# BaggingClassifier with KNeighborsClassifier
warnings.filterwarnings('ignore')
bag_knn=clasicalmodels(BaggingClassifier(n_estimators=15,estimator=svc),'BaggingClassifier_KNeighborsClassifier')
# Out:
# BaggingClassifier(estimator=SVC(C=100, gamma=100, random_state=42),
#                   n_estimators=15) :
# Train Accuracy : 0.9968
# Test  Accuracy : 0.9747
# Train Precision: 0.9969
# Test  Precision: 0.9757
# Train Recall   : 0.9968
# Test  Recall   : 0.9747
# Train F1 Score : 0.9968
# Test  F1 Score : 0.9745

# %%
# BaggingClassifier with GaussianNB
warnings.filterwarnings('ignore')
bag_gauss=clasicalmodels(BaggingClassifier(n_estimators=15,estimator=svc),'BaggingClassifier_GaussianNB')
# Out:
# BaggingClassifier(estimator=SVC(C=100, gamma=100, random_state=42),
#                   n_estimators=15) :
# Train Accuracy : 0.9977
# Test  Accuracy : 0.9819
# Train Precision: 0.9977
# Test  Precision: 0.9824
# Train Recall   : 0.9977
# Test  Recall   : 0.9819
# Train F1 Score : 0.9977
# Test  F1 Score : 0.9818

# %%
# GradientBoostingClassifier
warnings.filterwarnings('ignore')
gradc=clasicalmodels(GradientBoostingClassifier(n_estimators=100,learning_rate=0.1,max_depth=6,random_state=42)
,'GradientBoostingClassifier')
# Out:
# GradientBoostingClassifier(max_depth=6, random_state=42) :
# Train Accuracy : 1.0000
# Test  Accuracy : 0.9819
# Train Precision: 1.0000
# Test  Precision: 0.9820
# Train Recall   : 1.0000
# Test  Recall   : 0.9819
# Train F1 Score : 1.0000
# Test  F1 Score : 0.9819

# %%
# AdaBoostClassifier
warnings.filterwarnings('ignore')
adaboost=clasicalmodels(AdaBoostClassifier(n_estimators=25,learning_rate=0.5,random_state=42),'AdaBoostClassifier')
# Out:
# AdaBoostClassifier(learning_rate=0.5, n_estimators=25, random_state=42) :
# Train Accuracy : 0.7836
# Test  Accuracy : 0.7852
# Train Precision: 0.7788
# Test  Precision: 0.7801
# Train Recall   : 0.7836
# Test  Recall   : 0.7852
# Train F1 Score : 0.7779
# Test  F1 Score : 0.7803

# %%
# LinearDiscriminantAnalysis
warnings.filterwarnings('ignore')
bag_gauss=clasicalmodels(LinearDiscriminantAnalysis(),'LinearDiscriminantAnalysis')
# Out:
# LinearDiscriminantAnalysis() :
# Train Accuracy : 0.7814
# Test  Accuracy : 0.7744
# Train Precision: 0.7766
# Test  Precision: 0.7689
# Train Recall   : 0.7814
# Test  Recall   : 0.7744
# Train F1 Score : 0.7738
# Test  F1 Score : 0.7633

# %%
model_results
# Out:
#                                      Model  Train_Acc  Test_Acc  Train_Prec  \
# 0                   DecisionTreeClassifier   0.844625  0.846570    0.842985
# 1                   RandomForestClassifier   0.999548  0.978339    0.999549
# 2                       LogisticRegression   0.784101  0.774368    0.779594
# 3                     KNeighborsClassifier   0.890244  0.815884    0.895432
# 4                                      SVC   1.000000  0.987365    1.000000
# 5                               GaussianNB   0.766938  0.768953    0.762114
# 6     BaggingClassifier_LogisticRegression   0.781843  0.776173    0.777027
# 7                    BaggingClassifier_SVC   0.996838  0.978339    0.996854
# 8   BaggingClassifier_KNeighborsClassifier   0.996838  0.974729    0.996854
# 9             BaggingClassifier_GaussianNB   0.997742  0.981949    0.997749
# 10              GradientBoostingClassifier   1.000000  0.981949    1.000000
# 11                      AdaBoostClassifier   0.783650  0.785199    0.778817
# 12              LinearDiscriminantAnalysis   0.781391  0.774368    0.776639
#
#     Test_Prec  Train_Rec  Test_Rec  Train_F1   Test_F1
# 0    0.844829   0.844625  0.846570  0.841448  0.843038
# 1    0.978421   0.999548  0.978339  0.999548  0.978251
# 2    0.768939   0.784101  0.774368  0.776589  0.763339
# 3    0.813545   0.890244  0.815884  0.886396  0.809221
# 4    0.987601   1.000000  0.987365  1.000000  0.987304
# 5    0.763553   0.766938  0.768953  0.763164  0.764689
# 6    0.770628   0.781843  0.776173  0.774645  0.766040
# 7    0.979025   0.996838  0.978339  0.996835  0.978155
# 8    0.975658   0.996838  0.974729  0.996835  0.974474
# 9    0.982428   0.997742  0.981949  0.997740  0.981823
# 10   0.981967   1.000000  0.981949  1.000000  0.981901
# 11   0.780072   0.783650  0.785199  0.777894  0.780253
# 12   0.768939   0.781391  0.774368  0.773785  0.763339

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
device='cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
class FFN(nn.Module):
    def __init__(self):
        super().__init__()

        self.net = nn.Sequential(
            nn.Linear(8, 128),
            nn.ReLU(),

            nn.Linear(128, 256),
            nn.ReLU(),

            nn.Linear(256, 512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 256),
            nn.ReLU(),

            nn.Linear(256, 128),
            nn.ReLU(),

            nn.Linear(128, 2)
        )

    def forward(self, x):
        return self.net(x)

# %%
FNN_model = FFN()
FNN_model.to(device)
# Out:
# FFN(
#   (net): Sequential(
#     (0): Linear(in_features=8, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=512, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=512, out_features=512, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=512, out_features=256, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=256, out_features=128, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=128, out_features=2, bias=True)
#   )
# )

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X.values, dtype=torch.float32)
        self.y = torch.tensor(y.values.squeeze(), dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
train_dataset = CustomDataset(xtrain,ytrain)

# %%
test_dataset = CustomDataset(xtest,ytest)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=30, shuffle=True)

# %%
test_dataloader = DataLoader(test_dataset, batch_size=30, shuffle=True)

# %%
def accuracy_fn(y_true, y_pred):
    return (y_true == y_pred).sum().item() / len(y_true)

# %%
def train(model, epochs, train_dataloader=train_dataloader, device=device):
    torch.cuda.manual_seed_all(33)

    for epoch in range(epochs):
        model.train()
        avg_loss = 0.0
        avg_acc  = 0.0

        for step, (x, y) in enumerate(train_dataloader):
            x = x.to(device)
            y = y.to(device)

            optimizer.zero_grad()

            logits = model(x)              # shape: [B, 2]
            loss = loss_fn(logits, y)      # y: [B] with 0/1

            loss.backward()
            optimizer.step()

            preds = logits.argmax(dim=1)   # NO softmax
            acc = accuracy_fn(y, preds)

            avg_loss += loss.item()
            avg_acc  += acc

        avg_loss /= (step + 1)
        avg_acc  /= (step + 1)

        print(f"Epoch {epoch} | Avg Loss {avg_loss:.4f} | Avg Acc {avg_acc:.4f}")

# %%
loss_fn = nn.CrossEntropyLoss()  
optimizer = torch.optim.Adam(FNN_model.parameters(), lr=0.00001)

# %%
train(model=FNN_model,epochs=300)
# Out:
# Epoch 0 | Avg Loss 0.6649 | Avg Acc 0.6475
# Epoch 1 | Avg Loss 0.6428 | Avg Acc 0.6616
# Epoch 2 | Avg Loss 0.6276 | Avg Acc 0.6761
# Epoch 3 | Avg Loss 0.6162 | Avg Acc 0.6762
# Epoch 4 | Avg Loss 0.6064 | Avg Acc 0.6869
# Epoch 5 | Avg Loss 0.5994 | Avg Acc 0.6878
# Epoch 6 | Avg Loss 0.5943 | Avg Acc 0.6858
# Epoch 7 | Avg Loss 0.5881 | Avg Acc 0.6867
# Epoch 8 | Avg Loss 0.5836 | Avg Acc 0.6919
# Epoch 9 | Avg Loss 0.5795 | Avg Acc 0.6980
# Epoch 10 | Avg Loss 0.5764 | Avg Acc 0.6947
# Epoch 11 | Avg Loss 0.5724 | Avg Acc 0.6941
# Epoch 12 | Avg Loss 0.5708 | Avg Acc 0.7142
# Epoch 13 | Avg Loss 0.5665 | Avg Acc 0.7069
# Epoch 14 | Avg Loss 0.5630 | Avg Acc 0.7231
# Epoch 15 | Avg Loss 0.5612 | Avg Acc 0.7184
# Epoch 16 | Avg Loss 0.5565 | Avg Acc 0.7268
# Epoch 17 | Avg Loss 0.5559 | Avg Acc 0.7168
# Epoch 18 | Avg Loss 0.5518 | Avg Acc 0.7297
# Epoch 19 | Avg Loss 0.5487 | Avg Acc 0.7297
# Epoch 20 | Avg Loss 0.5473 | Avg Acc 0.7293
# Epoch 21 | Avg Loss 0.5464 | Avg Acc 0.7324
# Epoch 22 | Avg Loss 0.5439 | Avg Acc 0.7269
# Epoch 23 | Avg Loss 0.5402 | Avg Acc 0.7301
# Epoch 24 | Avg Loss 0.5381 | Avg Acc 0.7354
# Epoch 25 | Avg Loss 0.5376 | Avg Acc 0.7365
# Epoch 26 | Avg Loss 0.5340 | Avg Acc 0.7404
# Epoch 27 | Avg Loss 0.5311 | Avg Acc 0.7396
# Epoch 28 | Avg Loss 0.5308 | Avg Acc 0.7381
# Epoch 29 | Avg Loss 0.5276 | Avg Acc 0.7366
# Epoch 30 | Avg Loss 0.5253 | Avg Acc 0.7445
# Epoch 31 | Avg Loss 0.5264 | Avg Acc 0.7412
# Epoch 32 | Avg Loss 0.5209 | Avg Acc 0.7426
# Epoch 33 | Avg Loss 0.5190 | Avg Acc 0.7511
# Epoch 34 | Avg Loss 0.5178 | Avg Acc 0.7564
# Epoch 35 | Avg Loss 0.5147 | Avg Acc 0.7472
# Epoch 36 | Avg Loss 0.5151 | Avg Acc 0.7517
# Epoch 37 | Avg Loss 0.5128 | Avg Acc 0.7486
# Epoch 38 | Avg Loss 0.5119 | Avg Acc 0.7492
# Epoch 39 | Avg Loss 0.5077 | Avg Acc 0.7556
# Epoch 40 | Avg Loss 0.5046 | Avg Acc 0.7520
# Epoch 41 | Avg Loss 0.5079 | Avg Acc 0.7510
# Epoch 42 | Avg Loss 0.5049 | Avg Acc 0.7607
# Epoch 43 | Avg Loss 0.5012 | Avg Acc 0.7645
# Epoch 44 | Avg Loss 0.5024 | Avg Acc 0.7582
# Epoch 45 | Avg Loss 0.4975 | Avg Acc 0.7658
# Epoch 46 | Avg Loss 0.4964 | Avg Acc 0.7669
# Epoch 47 | Avg Loss 0.4969 | Avg Acc 0.7661
# Epoch 48 | Avg Loss 0.4966 | Avg Acc 0.7642
# Epoch 49 | Avg Loss 0.4925 | Avg Acc 0.7711
# Epoch 50 | Avg Loss 0.4931 | Avg Acc 0.7668
# Epoch 51 | Avg Loss 0.4931 | Avg Acc 0.7633
# Epoch 52 | Avg Loss 0.4914 | Avg Acc 0.7689
# Epoch 53 | Avg Loss 0.4878 | Avg Acc 0.7774
# Epoch 54 | Avg Loss 0.4858 | Avg Acc 0.7759
# Epoch 55 | Avg Loss 0.4899 | Avg Acc 0.7702
# Epoch 56 | Avg Loss 0.4807 | Avg Acc 0.7742
# Epoch 57 | Avg Loss 0.4793 | Avg Acc 0.7819
# Epoch 58 | Avg Loss 0.4805 | Avg Acc 0.7836
# Epoch 59 | Avg Loss 0.4818 | Avg Acc 0.7757
# Epoch 60 | Avg Loss 0.4776 | Avg Acc 0.7805
# Epoch 61 | Avg Loss 0.4758 | Avg Acc 0.7819
# Epoch 62 | Avg Loss 0.4706 | Avg Acc 0.7856
# Epoch 63 | Avg Loss 0.4746 | Avg Acc 0.7815
# Epoch 64 | Avg Loss 0.4679 | Avg Acc 0.7860
# Epoch 65 | Avg Loss 0.4707 | Avg Acc 0.7836
# Epoch 66 | Avg Loss 0.4687 | Avg Acc 0.7878
# Epoch 67 | Avg Loss 0.4648 | Avg Acc 0.7990
# Epoch 68 | Avg Loss 0.4655 | Avg Acc 0.7846
# Epoch 69 | Avg Loss 0.4602 | Avg Acc 0.7953
# Epoch 70 | Avg Loss 0.4610 | Avg Acc 0.7928
# Epoch 71 | Avg Loss 0.4616 | Avg Acc 0.7997
# Epoch 72 | Avg Loss 0.4585 | Avg Acc 0.7952
# Epoch 73 | Avg Loss 0.4544 | Avg Acc 0.7935
# Epoch 74 | Avg Loss 0.4570 | Avg Acc 0.7941
# Epoch 75 | Avg Loss 0.4505 | Avg Acc 0.7947
# Epoch 76 | Avg Loss 0.4532 | Avg Acc 0.7971
# Epoch 77 | Avg Loss 0.4506 | Avg Acc 0.7964
# Epoch 78 | Avg Loss 0.4456 | Avg Acc 0.8007
# Epoch 79 | Avg Loss 0.4465 | Avg Acc 0.8034
# Epoch 80 | Avg Loss 0.4453 | Avg Acc 0.7985
# Epoch 81 | Avg Loss 0.4439 | Avg Acc 0.8017
# Epoch 82 | Avg Loss 0.4398 | Avg Acc 0.8018
# Epoch 83 | Avg Loss 0.4396 | Avg Acc 0.8023
# Epoch 84 | Avg Loss 0.4420 | Avg Acc 0.7988
# Epoch 85 | Avg Loss 0.4365 | Avg Acc 0.8097
# Epoch 86 | Avg Loss 0.4342 | Avg Acc 0.8046
# Epoch 87 | Avg Loss 0.4323 | Avg Acc 0.8069
# Epoch 88 | Avg Loss 0.4296 | Avg Acc 0.8086
# Epoch 89 | Avg Loss 0.4291 | Avg Acc 0.8095
# Epoch 90 | Avg Loss 0.4253 | Avg Acc 0.8175
# Epoch 91 | Avg Loss 0.4261 | Avg Acc 0.8090
# Epoch 92 | Avg Loss 0.4262 | Avg Acc 0.8150
# Epoch 93 | Avg Loss 0.4273 | Avg Acc 0.8106
# Epoch 94 | Avg Loss 0.4211 | Avg Acc 0.8176
# Epoch 95 | Avg Loss 0.4188 | Avg Acc 0.8117
# Epoch 96 | Avg Loss 0.4242 | Avg Acc 0.8128
# Epoch 97 | Avg Loss 0.4163 | Avg Acc 0.8142
# Epoch 98 | Avg Loss 0.4131 | Avg Acc 0.8217
# Epoch 99 | Avg Loss 0.4115 | Avg Acc 0.8141
# Epoch 100 | Avg Loss 0.4145 | Avg Acc 0.8108
# Epoch 101 | Avg Loss 0.4083 | Avg Acc 0.8234
# Epoch 102 | Avg Loss 0.4148 | Avg Acc 0.8177
# Epoch 103 | Avg Loss 0.4056 | Avg Acc 0.8166
# Epoch 104 | Avg Loss 0.4067 | Avg Acc 0.8168
# Epoch 105 | Avg Loss 0.4049 | Avg Acc 0.8206
# Epoch 106 | Avg Loss 0.4058 | Avg Acc 0.8151
# Epoch 107 | Avg Loss 0.3968 | Avg Acc 0.8291
# Epoch 108 | Avg Loss 0.3984 | Avg Acc 0.8212
# Epoch 109 | Avg Loss 0.3994 | Avg Acc 0.8212
# Epoch 110 | Avg Loss 0.3996 | Avg Acc 0.8230
# Epoch 111 | Avg Loss 0.3954 | Avg Acc 0.8266
# Epoch 112 | Avg Loss 0.3885 | Avg Acc 0.8321
# Epoch 113 | Avg Loss 0.3867 | Avg Acc 0.8320
# Epoch 114 | Avg Loss 0.3867 | Avg Acc 0.8342
# Epoch 115 | Avg Loss 0.3856 | Avg Acc 0.8285
# Epoch 116 | Avg Loss 0.3849 | Avg Acc 0.8298
# Epoch 117 | Avg Loss 0.3895 | Avg Acc 0.8244
# Epoch 118 | Avg Loss 0.3830 | Avg Acc 0.8261
# Epoch 119 | Avg Loss 0.3790 | Avg Acc 0.8358
# Epoch 120 | Avg Loss 0.3775 | Avg Acc 0.8323
# Epoch 121 | Avg Loss 0.3768 | Avg Acc 0.8350
# Epoch 122 | Avg Loss 0.3726 | Avg Acc 0.8396
# Epoch 123 | Avg Loss 0.3723 | Avg Acc 0.8361
# Epoch 124 | Avg Loss 0.3751 | Avg Acc 0.8384
# Epoch 125 | Avg Loss 0.3720 | Avg Acc 0.8390
# Epoch 126 | Avg Loss 0.3683 | Avg Acc 0.8366
# Epoch 127 | Avg Loss 0.3622 | Avg Acc 0.8452
# Epoch 128 | Avg Loss 0.3620 | Avg Acc 0.8414
# Epoch 129 | Avg Loss 0.3727 | Avg Acc 0.8294
# Epoch 130 | Avg Loss 0.3657 | Avg Acc 0.8423
# Epoch 131 | Avg Loss 0.3614 | Avg Acc 0.8438
# Epoch 132 | Avg Loss 0.3581 | Avg Acc 0.8416
# Epoch 133 | Avg Loss 0.3573 | Avg Acc 0.8461
# Epoch 134 | Avg Loss 0.3557 | Avg Acc 0.8427
# Epoch 135 | Avg Loss 0.3621 | Avg Acc 0.8393
# Epoch 136 | Avg Loss 0.3528 | Avg Acc 0.8479
# Epoch 137 | Avg Loss 0.3548 | Avg Acc 0.8483
# Epoch 138 | Avg Loss 0.3465 | Avg Acc 0.8509
# Epoch 139 | Avg Loss 0.3476 | Avg Acc 0.8465
# Epoch 140 | Avg Loss 0.3407 | Avg Acc 0.8492
# Epoch 141 | Avg Loss 0.3493 | Avg Acc 0.8443
# Epoch 142 | Avg Loss 0.3405 | Avg Acc 0.8530
# Epoch 143 | Avg Loss 0.3380 | Avg Acc 0.8493
# Epoch 144 | Avg Loss 0.3465 | Avg Acc 0.8484
# Epoch 145 | Avg Loss 0.3359 | Avg Acc 0.8560
# Epoch 146 | Avg Loss 0.3337 | Avg Acc 0.8521
# Epoch 147 | Avg Loss 0.3416 | Avg Acc 0.8515
# Epoch 148 | Avg Loss 0.3330 | Avg Acc 0.8605
# Epoch 149 | Avg Loss 0.3343 | Avg Acc 0.8559
# Epoch 150 | Avg Loss 0.3334 | Avg Acc 0.8538
# Epoch 151 | Avg Loss 0.3511 | Avg Acc 0.8466
# Epoch 152 | Avg Loss 0.3444 | Avg Acc 0.8553
# Epoch 153 | Avg Loss 0.3244 | Avg Acc 0.8563
# Epoch 154 | Avg Loss 0.3220 | Avg Acc 0.8630
# Epoch 155 | Avg Loss 0.3241 | Avg Acc 0.8613
# Epoch 156 | Avg Loss 0.3247 | Avg Acc 0.8572
# Epoch 157 | Avg Loss 0.3195 | Avg Acc 0.8599
# Epoch 158 | Avg Loss 0.3253 | Avg Acc 0.8562
# Epoch 159 | Avg Loss 0.3226 | Avg Acc 0.8532
# Epoch 160 | Avg Loss 0.3240 | Avg Acc 0.8555
# Epoch 161 | Avg Loss 0.3194 | Avg Acc 0.8646
# Epoch 162 | Avg Loss 0.3146 | Avg Acc 0.8678
# Epoch 163 | Avg Loss 0.3146 | Avg Acc 0.8697
# Epoch 164 | Avg Loss 0.3133 | Avg Acc 0.8664
# Epoch 165 | Avg Loss 0.3099 | Avg Acc 0.8678
# Epoch 166 | Avg Loss 0.3058 | Avg Acc 0.8726
# Epoch 167 | Avg Loss 0.3154 | Avg Acc 0.8601
# Epoch 168 | Avg Loss 0.3047 | Avg Acc 0.8626
# Epoch 169 | Avg Loss 0.3033 | Avg Acc 0.8736
# Epoch 170 | Avg Loss 0.3050 | Avg Acc 0.8684
# Epoch 171 | Avg Loss 0.2985 | Avg Acc 0.8739
# Epoch 172 | Avg Loss 0.2995 | Avg Acc 0.8724
# Epoch 173 | Avg Loss 0.2996 | Avg Acc 0.8667
# Epoch 174 | Avg Loss 0.3014 | Avg Acc 0.8667
# Epoch 175 | Avg Loss 0.2986 | Avg Acc 0.8632
# Epoch 176 | Avg Loss 0.3010 | Avg Acc 0.8724
# Epoch 177 | Avg Loss 0.3128 | Avg Acc 0.8622
# Epoch 178 | Avg Loss 0.2946 | Avg Acc 0.8752
# Epoch 179 | Avg Loss 0.2930 | Avg Acc 0.8742
# Epoch 180 | Avg Loss 0.2910 | Avg Acc 0.8711
# Epoch 181 | Avg Loss 0.2880 | Avg Acc 0.8735
# Epoch 182 | Avg Loss 0.2867 | Avg Acc 0.8761
# Epoch 183 | Avg Loss 0.2840 | Avg Acc 0.8757
# Epoch 184 | Avg Loss 0.2836 | Avg Acc 0.8855
# Epoch 185 | Avg Loss 0.2862 | Avg Acc 0.8740
# Epoch 186 | Avg Loss 0.2822 | Avg Acc 0.8738
# Epoch 187 | Avg Loss 0.2803 | Avg Acc 0.8823
# Epoch 188 | Avg Loss 0.2838 | Avg Acc 0.8761
# Epoch 189 | Avg Loss 0.2835 | Avg Acc 0.8825
# Epoch 190 | Avg Loss 0.2887 | Avg Acc 0.8735
# Epoch 191 | Avg Loss 0.2794 | Avg Acc 0.8778
# Epoch 192 | Avg Loss 0.2773 | Avg Acc 0.8863
# Epoch 193 | Avg Loss 0.2733 | Avg Acc 0.8845
# Epoch 194 | Avg Loss 0.2754 | Avg Acc 0.8813
# Epoch 195 | Avg Loss 0.2668 | Avg Acc 0.8843
# Epoch 196 | Avg Loss 0.2774 | Avg Acc 0.8830
# Epoch 197 | Avg Loss 0.2845 | Avg Acc 0.8735
# Epoch 198 | Avg Loss 0.2672 | Avg Acc 0.8851
# Epoch 199 | Avg Loss 0.2646 | Avg Acc 0.8875
# Epoch 200 | Avg Loss 0.2723 | Avg Acc 0.8832
# Epoch 201 | Avg Loss 0.2721 | Avg Acc 0.8805
# Epoch 202 | Avg Loss 0.2667 | Avg Acc 0.8902
# Epoch 203 | Avg Loss 0.2590 | Avg Acc 0.8908
# Epoch 204 | Avg Loss 0.2704 | Avg Acc 0.8815
# Epoch 205 | Avg Loss 0.2533 | Avg Acc 0.8967
# Epoch 206 | Avg Loss 0.2629 | Avg Acc 0.8886
# Epoch 207 | Avg Loss 0.2652 | Avg Acc 0.8856
# Epoch 208 | Avg Loss 0.2503 | Avg Acc 0.8948
# Epoch 209 | Avg Loss 0.2582 | Avg Acc 0.8894
# Epoch 210 | Avg Loss 0.2634 | Avg Acc 0.8914
# Epoch 211 | Avg Loss 0.2448 | Avg Acc 0.9016
# Epoch 212 | Avg Loss 0.2520 | Avg Acc 0.8970
# Epoch 213 | Avg Loss 0.2476 | Avg Acc 0.8986
# Epoch 214 | Avg Loss 0.2519 | Avg Acc 0.8943
# Epoch 215 | Avg Loss 0.2514 | Avg Acc 0.8958
# Epoch 216 | Avg Loss 0.2454 | Avg Acc 0.8964
# Epoch 217 | Avg Loss 0.2560 | Avg Acc 0.8875
# Epoch 218 | Avg Loss 0.2625 | Avg Acc 0.8920
# Epoch 219 | Avg Loss 0.2416 | Avg Acc 0.9055
# Epoch 220 | Avg Loss 0.2352 | Avg Acc 0.9062
# Epoch 221 | Avg Loss 0.2420 | Avg Acc 0.8965
# Epoch 222 | Avg Loss 0.2424 | Avg Acc 0.9001
# Epoch 223 | Avg Loss 0.2621 | Avg Acc 0.8889
# Epoch 224 | Avg Loss 0.2431 | Avg Acc 0.8950
# Epoch 225 | Avg Loss 0.2358 | Avg Acc 0.9056
# Epoch 226 | Avg Loss 0.2477 | Avg Acc 0.8929
# Epoch 227 | Avg Loss 0.2408 | Avg Acc 0.9012
# Epoch 228 | Avg Loss 0.2378 | Avg Acc 0.9044
# Epoch 229 | Avg Loss 0.2377 | Avg Acc 0.9046
# Epoch 230 | Avg Loss 0.2337 | Avg Acc 0.9037
# Epoch 231 | Avg Loss 0.2398 | Avg Acc 0.9014
# Epoch 232 | Avg Loss 0.2242 | Avg Acc 0.9164
# Epoch 233 | Avg Loss 0.2231 | Avg Acc 0.9143
# Epoch 234 | Avg Loss 0.2279 | Avg Acc 0.9083
# Epoch 235 | Avg Loss 0.2345 | Avg Acc 0.9052
# Epoch 236 | Avg Loss 0.2276 | Avg Acc 0.9126
# Epoch 237 | Avg Loss 0.2215 | Avg Acc 0.9125
# Epoch 238 | Avg Loss 0.2252 | Avg Acc 0.9124
# Epoch 239 | Avg Loss 0.2247 | Avg Acc 0.9107
# Epoch 240 | Avg Loss 0.2305 | Avg Acc 0.9048
# Epoch 241 | Avg Loss 0.2322 | Avg Acc 0.9023
# Epoch 242 | Avg Loss 0.2220 | Avg Acc 0.9126
# Epoch 243 | Avg Loss 0.2152 | Avg Acc 0.9205
# Epoch 244 | Avg Loss 0.2245 | Avg Acc 0.9087
# Epoch 245 | Avg Loss 0.2254 | Avg Acc 0.9056
# Epoch 246 | Avg Loss 0.2226 | Avg Acc 0.9089
# Epoch 247 | Avg Loss 0.2231 | Avg Acc 0.9114
# Epoch 248 | Avg Loss 0.2040 | Avg Acc 0.9282
# Epoch 249 | Avg Loss 0.2158 | Avg Acc 0.9155
# Epoch 250 | Avg Loss 0.2097 | Avg Acc 0.9253
# Epoch 251 | Avg Loss 0.2139 | Avg Acc 0.9182
# Epoch 252 | Avg Loss 0.2060 | Avg Acc 0.9216
# Epoch 253 | Avg Loss 0.2218 | Avg Acc 0.9082
# Epoch 254 | Avg Loss 0.2051 | Avg Acc 0.9184
# Epoch 255 | Avg Loss 0.2048 | Avg Acc 0.9202
# Epoch 256 | Avg Loss 0.1993 | Avg Acc 0.9301
# Epoch 257 | Avg Loss 0.2033 | Avg Acc 0.9260
# Epoch 258 | Avg Loss 0.2025 | Avg Acc 0.9275
# Epoch 259 | Avg Loss 0.2011 | Avg Acc 0.9275
# Epoch 260 | Avg Loss 0.1993 | Avg Acc 0.9256
# Epoch 261 | Avg Loss 0.2145 | Avg Acc 0.9193
# Epoch 262 | Avg Loss 0.2080 | Avg Acc 0.9152
# Epoch 263 | Avg Loss 0.1969 | Avg Acc 0.9292
# Epoch 264 | Avg Loss 0.1957 | Avg Acc 0.9318
# Epoch 265 | Avg Loss 0.2129 | Avg Acc 0.9135
# Epoch 266 | Avg Loss 0.2026 | Avg Acc 0.9218
# Epoch 267 | Avg Loss 0.2053 | Avg Acc 0.9189
# Epoch 268 | Avg Loss 0.2005 | Avg Acc 0.9269
# Epoch 269 | Avg Loss 0.1960 | Avg Acc 0.9270
# Epoch 270 | Avg Loss 0.2011 | Avg Acc 0.9233
# Epoch 271 | Avg Loss 0.1920 | Avg Acc 0.9292
# Epoch 272 | Avg Loss 0.1921 | Avg Acc 0.9277
# Epoch 273 | Avg Loss 0.1874 | Avg Acc 0.9313
# Epoch 274 | Avg Loss 0.1867 | Avg Acc 0.9383
# Epoch 275 | Avg Loss 0.1984 | Avg Acc 0.9230
# Epoch 276 | Avg Loss 0.1924 | Avg Acc 0.9293
# Epoch 277 | Avg Loss 0.1901 | Avg Acc 0.9288
# Epoch 278 | Avg Loss 0.1936 | Avg Acc 0.9211
# Epoch 279 | Avg Loss 0.1939 | Avg Acc 0.9287
# Epoch 280 | Avg Loss 0.1811 | Avg Acc 0.9342
# Epoch 281 | Avg Loss 0.1779 | Avg Acc 0.9347
# Epoch 282 | Avg Loss 0.1932 | Avg Acc 0.9279
# Epoch 283 | Avg Loss 0.1872 | Avg Acc 0.9195
# Epoch 284 | Avg Loss 0.1785 | Avg Acc 0.9420
# Epoch 285 | Avg Loss 0.1752 | Avg Acc 0.9419
# Epoch 286 | Avg Loss 0.1807 | Avg Acc 0.9315
# Epoch 287 | Avg Loss 0.1806 | Avg Acc 0.9292
# Epoch 288 | Avg Loss 0.1906 | Avg Acc 0.9275
# Epoch 289 | Avg Loss 0.1695 | Avg Acc 0.9447
# Epoch 290 | Avg Loss 0.1726 | Avg Acc 0.9374
# Epoch 291 | Avg Loss 0.1728 | Avg Acc 0.9373
# Epoch 292 | Avg Loss 0.1775 | Avg Acc 0.9306
# Epoch 293 | Avg Loss 0.1692 | Avg Acc 0.9471
# Epoch 294 | Avg Loss 0.1650 | Avg Acc 0.9439
# Epoch 295 | Avg Loss 0.1729 | Avg Acc 0.9354
# Epoch 296 | Avg Loss 0.1880 | Avg Acc 0.9249
# Epoch 297 | Avg Loss 0.1766 | Avg Acc 0.9351
# Epoch 298 | Avg Loss 0.1723 | Avg Acc 0.9395
# Epoch 299 | Avg Loss 0.1682 | Avg Acc 0.9385

# %%
xtrain = torch.tensor(xtrain.values, dtype=torch.float32)
xtest  = torch.tensor(xtest.values,  dtype=torch.float32)
ytrain = torch.tensor(ytrain.values, dtype=torch.long)
ytest  = torch.tensor(ytest.values,  dtype=torch.long)

# %%
xtrain = xtrain.to(device)
ytrain = ytrain.to(device)
xtest = xtest.to(device)
ytest = ytest.to(device)

# %%
def evaluate_model(model, loader, device):
    model.eval()
    y_true, y_pred = [], []
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            p = model(x).argmax(1)
            y_true.extend(y.cpu())
            y_pred.extend(p.cpu())
    y_true, y_pred = torch.tensor(y_true), torch.tensor(y_pred)
    return {
        "acc": (y_true == y_pred).float().mean().item(),
        "precision": precision_score(y_true, y_pred, average="weighted"),
        "recall": recall_score(y_true, y_pred, average="weighted"),
        "f1": f1_score(y_true, y_pred, average="weighted"),
        "cm": confusion_matrix(y_true, y_pred)
    }

# %%
def plot_cm_and_store(model, train_loader, test_loader, device, model_results, name="FFN"):
    tr = evaluate_model(model, train_loader, device)
    te = evaluate_model(model, test_loader, device)

    print("Train Accuracy :", tr["acc"])
    print("Test  Accuracy :", te["acc"])
    print("Train Precision:", tr["precision"])
    print("Test  Precision:", te["precision"])
    print("Train Recall   :", tr["recall"])
    print("Test  Recall   :", te["recall"])
    print("Train F1-score :", tr["f1"])
    print("Test  F1-score :", te["f1"])

    fig, ax = plt.subplots(1, 2, figsize=(10, 4))
    sns.heatmap(tr["cm"], annot=True, fmt="d", ax=ax[0], cbar=False)
    ax[0].set_title(f"Train Acc = {tr['acc']:.3f}")
    sns.heatmap(te["cm"], annot=True, fmt="d", ax=ax[1], cbar=False)
    ax[1].set_title(f"Test Acc = {te['acc']:.3f}")
    plt.tight_layout(); plt.show()

    model_results.loc[len(model_results)] = [
        name,
        tr["acc"], te["acc"],
        tr["precision"], te["precision"],
        tr["recall"], te["recall"],
        tr["f1"], te["f1"]
    ]

# %%
plot_cm_and_store(FNN_model, train_dataloader, test_dataloader, device,model_results)
# Out:
# Train Accuracy : 0.9489611387252808
# Test  Accuracy : 0.929602861404419
# Train Precision: 0.9491347345643999
# Test  Precision: 0.9299336232834239
# Train Recall   : 0.9489611562782294
# Test  Recall   : 0.9296028880866426
# Train F1-score : 0.9490308929068048
# Test  F1-score : 0.929738528978361

# %%
model_results
# Out:
#                                      Model  Train_Acc  Test_Acc  Train_Prec  \
# 0                   DecisionTreeClassifier   0.844625  0.846570    0.842985
# 1                   RandomForestClassifier   0.999548  0.978339    0.999549
# 2                       LogisticRegression   0.784101  0.774368    0.779594
# 3                     KNeighborsClassifier   0.890244  0.815884    0.895432
# 4                                      SVC   1.000000  0.987365    1.000000
# 5                               GaussianNB   0.766938  0.768953    0.762114
# 6     BaggingClassifier_LogisticRegression   0.781843  0.776173    0.777027
# 7                    BaggingClassifier_SVC   0.996838  0.978339    0.996854
# 8   BaggingClassifier_KNeighborsClassifier   0.996838  0.974729    0.996854
# 9             BaggingClassifier_GaussianNB   0.997742  0.981949    0.997749
# 10              GradientBoostingClassifier   1.000000  0.981949    1.000000
# 11                      AdaBoostClassifier   0.783650  0.785199    0.778817
# 12              LinearDiscriminantAnalysis   0.781391  0.774368    0.776639
# 13                                     FFN   0.948961  0.929603    0.949135
#
#     Test_Prec  Train_Rec  Test_Rec  Train_F1   Test_F1
# 0    0.844829   0.844625  0.846570  0.841448  0.843038
# 1    0.978421   0.999548  0.978339  0.999548  0.978251
# 2    0.768939   0.784101  0.774368  0.776589  0.763339
# 3    0.813545   0.890244  0.815884  0.886396  0.809221
# 4    0.987601   1.000000  0.987365  1.000000  0.987304
# 5    0.763553   0.766938  0.768953  0.763164  0.764689
# 6    0.770628   0.781843  0.776173  0.774645  0.766040
# 7    0.979025   0.996838  0.978339  0.996835  0.978155
# 8    0.975658   0.996838  0.974729  0.996835  0.974474
# 9    0.982428   0.997742  0.981949  0.997740  0.981823
# 10   0.981967   1.000000  0.981949  1.000000  0.981901
# 11   0.780072   0.783650  0.785199  0.777894  0.780253
# 12   0.768939   0.781391  0.774368  0.773785  0.763339
# 13   0.929934   0.948961  0.929603  0.949031  0.929739

# %%
def plot_model_metrics1(df):
    metrics = ['Acc', 'Prec', 'Rec', 'F1']
    sns.set(style="whitegrid", font_scale=1.2)

    fig, axes = plt.subplots(2, 3, figsize=(32, 20))
    axes = axes.flatten()

    palette_train = ["#88ccee", "#44aa99"]  # soft cyan / turquoise
    palette_test  = ["#ddcc77", "#cc6677"]  # soft mustard / rose
    palette_summary = ["#fb9a99", "#e31a1c", "#fdbf6f"]  # pink / red / peach


    # 1-4
    for i, m in enumerate(metrics):
        df_long = df[['Model', f'Train_{m}', f'Test_{m}']].copy()
        df_long = df_long.melt('Model', var_name='Dataset', value_name='Score')
        df_long['Dataset'] = df_long['Dataset'].apply(lambda x: 'Train' if 'Train' in x else 'Test')

        sns.barplot(x='Model', y='Score', hue='Dataset', data=df_long,
                    palette=[palette_train[0], palette_test[0]], ax=axes[i])
        axes[i].set_title(f'{m} - Train vs Test', fontsize=16)
        axes[i].set_ylim(0, 1.05)
        axes[i].tick_params(axis='x', rotation=30)

    # 5
    summary_list = []
    for m in metrics:
        summary_list.append({
            'Metric': m,
            'Max': df[f'Train_{m}'].max(),
            'Min': df[f'Train_{m}'].min(),
            'Avg': df[f'Train_{m}'].mean()
        })
    summary_train = pd.DataFrame(summary_list).melt(id_vars='Metric',
                                                    var_name='Stat', value_name='Score')

    sns.barplot(x='Metric', y='Score', hue='Stat', data=summary_train,
                palette=palette_summary, ax=axes[4])
    axes[4].set_title('Train Summary (Max / Min / Avg)', fontsize=16)
    axes[4].set_ylim(0, 1.05)
    for container in axes[4].containers:  # annotate only summary
        axes[4].bar_label(container, fmt="%.3f", padding=3)

    # 6
    summary_list = []
    for m in metrics:
        summary_list.append({
            'Metric': m,
            'Max': df[f'Test_{m}'].max(),
            'Min': df[f'Test_{m}'].min(),
            'Avg': df[f'Test_{m}'].mean()
        })
    summary_test = pd.DataFrame(summary_list).melt(id_vars='Metric',
                                                   var_name='Stat', value_name='Score')

    sns.barplot(x='Metric', y='Score', hue='Stat', data=summary_test,
                palette=palette_summary, ax=axes[5])
    axes[5].set_title('Test Summary (Max / Min / Avg)', fontsize=16)
    axes[5].set_ylim(0, 1.05)
    for container in axes[5].containers:  # annotate only summary
        axes[5].bar_label(container, fmt="%.3f", padding=3)

    plt.tight_layout()
    plt.show()

# %%
plot_model_metrics1(model_results)

# %%
def plot_model_metrics2(df):
    metrics = ['Acc', 'Prec', 'Rec', 'F1']
    sns.set(style="whitegrid", font_scale=1.2)

    palette_train = ["#88ccee", "#44aa99"]      # soft cyan / turquoise
    palette_test  = ["#ddcc77", "#cc6677"]      # soft mustard / rose
    palette_summary = ["#fb9a99", "#e31a1c", "#fdbf6f"]  # pink / red / peach

    # 1-4
    for m in metrics:
        df_long = df[['Model', f'Train_{m}', f'Test_{m}']].copy()
        df_long = df_long.melt('Model', var_name='Dataset', value_name='Score')
        df_long['Dataset'] = df_long['Dataset'].apply(lambda x: 'Train' if 'Train' in x else 'Test')

        plt.figure(figsize=(16, 8))
        sns.barplot(x='Model', y='Score', hue='Dataset', data=df_long,
                    palette=[palette_train[0], palette_test[0]])
        plt.title(f'{m} - Train vs Test', fontsize=18)
        plt.ylim(0, 1.05)
        plt.xticks(rotation=30)
        plt.tight_layout()
        plt.show()

    # 5
    summary_list = []
    for m in metrics:
        summary_list.append({
            'Metric': m,
            'Max': df[f'Train_{m}'].max(),
            'Min': df[f'Train_{m}'].min(),
            'Avg': df[f'Train_{m}'].mean()
        })
    summary_train = pd.DataFrame(summary_list).melt(id_vars='Metric',
                                                    var_name='Stat', value_name='Score')

    plt.figure(figsize=(16, 8))
    sns.barplot(x='Metric', y='Score', hue='Stat', data=summary_train,
                palette=palette_summary)
    plt.title('Train Summary (Max / Min / Avg)', fontsize=18)
    plt.ylim(0, 1.05)
    for container in plt.gca().containers:
        plt.gca().bar_label(container, fmt="%.3f", padding=3)
    plt.tight_layout()
    plt.show()

    # 6
    summary_list = []
    for m in metrics:
        summary_list.append({
            'Metric': m,
            'Max': df[f'Test_{m}'].max(),
            'Min': df[f'Test_{m}'].min(),
            'Avg': df[f'Test_{m}'].mean()
        })
    summary_test = pd.DataFrame(summary_list).melt(id_vars='Metric',
                                                   var_name='Stat', value_name='Score')

    plt.figure(figsize=(16, 8))
    sns.barplot(x='Metric', y='Score', hue='Stat', data=summary_test,
                palette=palette_summary)
    plt.title('Test Summary (Max / Min / Avg)', fontsize=18)
    plt.ylim(0, 1.05)
    for container in plt.gca().containers:
        plt.gca().bar_label(container, fmt="%.3f", padding=3)
    plt.tight_layout()
    plt.show()

# %%
plot_model_metrics2(model_results)

# %%
def pred_fn(model_path):
    import numpy as np
    from joblib import load

    model = load(model_path)

    Pregnancies = int(input("Pregnancies: "))
    Glucose = float(input("Glucose: "))
    BloodPressure = float(input("Blood Pressure: "))
    SkinThickness = float(input("Skin Thickness: "))
    Insulin = float(input("Insulin: "))
    BMI = float(input("BMI: "))
    DiabetesPedigreeFunction = float(input("Diabetes Pedigree Function: "))
    Age = int(input("Age: "))

    feat = np.array([
        Pregnancies,
        Glucose,
        BloodPressure,
        SkinThickness,
        Insulin,
        BMI,
        DiabetesPedigreeFunction,
        Age
    ], dtype=float).reshape(1, -1)

    resdict = {
        0: "You do not have Diabetes",
        1: "You have Diabetes"
    }

    pred = model.predict(feat)[0]
    print("\nPrediction:", resdict[int(pred)], "\n")

    return pred

# %%
from pathlib import Path 
root=Path('models')
root.mkdir(exist_ok=True)
path = root / 'RandomForestClassifier.pkl'

# %%
6	148	72	35	0	33.6	0.627	50   1

# %%
pred_fn(model_path=path)
# Out:
# Pregnancies:  6
# Glucose:  148
# Blood Pressure:  72
# Skin Thickness:  35
# Insulin:  0
# BMI:  33.6
# Diabetes Pedigree Function:  0.627
# Age:  50
# Prediction: You have Diabetes
# np.int64(1)
